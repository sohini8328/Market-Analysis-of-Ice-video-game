# %% [markdown]
# ## Market Analysis for Ice video game store
#
# ###  Introduction
# #### The purpose of this project is to figure out most successful video games in market and also look at some traits which adds to its success. It will also help Ice to design their advertising campaign. By this analysis we can do sales forecast for 2017. This project will also help us to investigate on most profitable game, platform for the company.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
# Good introduction!
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>  Reviewer's comment </h2>
#
#
# Please do not forget about project titles :)
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from scipy import stats as st

# %%
# reading the dataframe
df = pd.read_csv('/datasets/games.csv')

# %%
## changing the columns to lower case to avoid errors
df.columns = df.columns.str.lower()

# %%
# pring first 5 rows of dataframe
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
# looking at all data types to make sure that they are in correct form
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# Finding missing values
df.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %%
# filling missing values with 0
df['critic_score']= df['critic_score'].fillna(0)

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
# I would first make sure there are no zeros in the data.
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
# I recommend that you print the number of zeros in the data :) </div>

# %%
# filling NaN values
df['rating']= df['rating'].fillna('not_rated')

# %%
#filling missing values
df['year_of_release'] = df['year_of_release'].fillna(0)

# %%
# checking duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
df['name'].duplicated().sum()
# Out:
# 5155

# %%
df['name'].unique()
# Out:
# array(['Wii Sports', 'Super Mario Bros.', 'Mario Kart Wii', ...,
#        'Woody Woodpecker in Crazy Castle 5', 'LMA Manager 2007',
#        'Haitaka no Psychedelica'], dtype=object)

# %%
df['platform'].duplicated().sum()
# Out:
# 16684

# %%
df['platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df['year_of_release'].duplicated().sum()
# Out:
# 16677

# %%
df['year_of_release'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,    0., 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %%
df['rating'].duplicated().sum()
# Out:
# 16706

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Yes, it's very important to check for the duplicates. Sometimes they can impair the quality of the analysis.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Very good! However, there can be unobvious duplicates, or duplicates in multiple columns. For example, there may be rows that have the same game's name, genre, year of release, platform and age rating, but they may have different user scores for some reason.
#
#
#
# Try to search them in a columns `'name', 'platform', 'year_of_release'`, for instance.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
#
# Would you please try to look for these tricky duplicates where name, platform and year are the same?
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 </b>
#
#
# Please try to look for these tricky duplicates where name, platform and year are the same.
# </div>

# %%
# looking for tricky duplicates
print(df.duplicated(subset= ['name', 'platform','year_of_release'], keep = False).sum())
# Out:
# 4

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
#
# Good! However, you only print the first and last rows with the boolean values. Can we make any inference based on 10 values? isn't it better to print their number?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 5 </h2>
#
#
# Correct.
# </div>

# %% [markdown]
# #### There were no tricky duplicates found

# %%
df['year_of_release'] = df['year_of_release'].astype(int)

# %% [markdown]
# #### The year_of_release has been converted to integer as it was float before. I filled the missing values with 0 so that the calculations can be done easily.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
#
# If you look at the unique values, you will notice that there are zeros. See the code below.  The code `df[df['user_score']== 0]` will not work here because the column has the `object` type.
# </div>

# %%
## check if data has zero and converting to numeric values 
df['user_score'] = pd.to_numeric(df['user_score'], errors ='coerce')

# %%
# Reviewer's code 2
df['user_score'].unique()
# Out:
# array([8. , nan, 8.3, 8.5, 6.6, 8.4, 8.6, 7.7, 6.3, 7.4, 8.2, 9. , 7.9,
#        8.1, 8.7, 7.1, 3.4, 5.3, 4.8, 3.2, 8.9, 6.4, 7.8, 7.5, 2.6, 7.2,
#        9.2, 7. , 7.3, 4.3, 7.6, 5.7, 5. , 9.1, 6.5, 8.8, 6.9, 9.4, 6.8,
#        6.1, 6.7, 5.4, 4. , 4.9, 4.5, 9.3, 6.2, 4.2, 6. , 3.7, 4.1, 5.8,
#        5.6, 5.5, 4.4, 4.6, 5.9, 3.9, 3.1, 2.9, 5.2, 3.3, 4.7, 5.1, 3.5,
#        2.5, 1.9, 3. , 2.7, 2.2, 2. , 9.5, 2.1, 3.6, 2.8, 1.8, 3.8, 0. ,
#        1.6, 9.6, 2.4, 1.7, 1.1, 0.3, 1.5, 0.7, 1.2, 2.3, 0.5, 1.3, 0.2,
#        0.6, 1.4, 0.9, 1. , 9.7])

# %%
# filling missing values
df['user_score']= df['user_score'].fillna(0)
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score     rating
# 0     28.96      3.77         8.45          76.0         8.0          E
# 1      3.58      6.81         0.77           0.0         0.0  not_rated
# 2     12.76      3.79         3.29          82.0         8.3          E
# 3     10.93      3.28         2.95          80.0         8.0          E
# 4      8.89     10.22         1.00           0.0         0.0  not_rated

# %%
df['user_score'] = df['user_score'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     16715 non-null  float64
#  9   user_score       16715 non-null  float64
#  10  rating           16715 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.isna().sum()
# Out:
# name               2
# platform           0
# year_of_release    0
# genre              2
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# dtype: int64

# %%
df.dropna()
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 0         41.36     28.96      3.77         8.45          76.0         8.0
# 1         29.08      3.58      6.81         0.77           0.0         0.0
# 2         15.68     12.76      3.79         3.29          82.0         8.3
# 3         15.61     10.93      3.28         2.95          80.0         8.0
# 4         11.27      8.89     10.22         1.00           0.0         0.0
# ...         ...       ...       ...          ...           ...         ...
# 16710      0.00      0.00      0.01         0.00           0.0         0.0
# 16711      0.00      0.01      0.00         0.00           0.0         0.0
# 16712      0.00      0.00      0.01         0.00           0.0         0.0
# 16713      0.01      0.00      0.00         0.00           0.0         0.0
# 16714      0.00      0.00      0.01         0.00           0.0         0.0
#
#           rating
# 0              E
# 1      not_rated
# 2              E
# 3              E
# 4      not_rated
# ...          ...
# 16710  not_rated
# 16711  not_rated
# 16712  not_rated
# 16713  not_rated
# 16714  not_rated
#
# [16713 rows x 11 columns]

# %% [markdown]
# #### From above graph I noticed that a platform takes around 8 years to fade away. As we see DS platform from 2007 to 2013 (6 years), PS2 from 2007 to 2011(4 years), PSP from 2007 to 2015(8 years). These are some examples from the box plot above.

# %% [markdown]
# ##### I have to change the user_score column to float but I notice some of the scores have 'tbd' because user is still deciding. As string cannot be converted to float  So for our analysis to happen hassel free I have dropped those rows. I assume the data was automatically collected, and some games just do not have enough scores to have some average. The scores columns we have here represent the averages.The data can be missing because maybe the data entry personnel forgot to enter data. Maybe some data was still in processing. Thats why it might be missing.

# %%
# Handle erroneous data
df = df[~((df['platform'] == 'DS') & (df['year_of_release'] > 0) & (df['year_of_release'] < 2004))]

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
# I assume the data was automatically collected, and some games just do not have enough scores to have some average. The scores columns we have here represent the averages.
#
# </div>

# %% [markdown]
# ## New Column

# %%
df['total_sales'] = df[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score     rating  \
# 0     28.96      3.77         8.45          76.0         8.0          E
# 1      3.58      6.81         0.77           0.0         0.0  not_rated
# 2     12.76      3.79         3.29          82.0         8.3          E
# 3     10.93      3.28         2.95          80.0         8.0          E
# 4      8.89     10.22         1.00           0.0         0.0  not_rated
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# 3        32.77
# 4        31.38

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
# You can also use **sum** with **axis=1** argument:
# </div>
#
# ```python
#
#
# df['total_sales'] = df[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)
# ```

# %% [markdown]
# ### I noticed that a platform takes around 8 years to fade away so if we want to forecast for 2017 we would only need the data which is under 8 years. The data more than 8 years is not very useful for our analysis.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# Would you please explain why you take a specific step?
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2</h2>
#
#
# >  I noticed that a platform takes around 10 years to fade
#
#
# How? You did not show it before you make the slice. Please follow the directions. There's a reason why we first analyze the whole distribution, why we then analyze top platforms and so on. So far it is not clear why you take this slice and since you deleted some years at this stage, you cannot finish first two tasks described in the "Brief".
#
# </div>

# %% [markdown]
# ## Analysis of Data

# %%
game_released =df.groupby('year_of_release')['name'].count()
game_released.head(50)
# Out:
# year_of_release
# 0        269
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      13
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      41
# 1992      43
# 1993      60
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1998     379
# 1999     338
# 2000     350
# 2001     482
# 2002     829
# 2003     775
# 2004     762
# 2005     939
# 2006    1006
# 2007    1197
# 2008    1427
# 2009    1426
# 2010    1255
# 2011    1136
# 2012     653
# 2013     544
# 2014     581
# 2015     606
# 2016     502
# Name: name, dtype: int64

# %% [markdown]
# ### As I am looking at the games released in different years I noticed highest amount of games were released from 2007 to  2011 maybe because entry to the market for new competitors were easier or government policies were linient so you can create and release more games. Another reason the demand increased a lot.

# %% [markdown]
# ### Games with most sales is Grand Theft Auto V followed by Mario Kart Wii. The games with worst performance G1 Jockey 4 2008, Seisou no Amazones and Cabbage Patch kids.

# %%
platform_sales = df.groupby('platform')['total_sales'].sum().sort_values(ascending= False)
platform_sales
# Out:
# platform
# PS2     1255.77
# X360     971.42
# PS3      939.65
# Wii      907.51
# DS       806.10
# PS       730.86
# GBA      317.85
# PS4      314.14
# PSP      294.05
# PC       259.52
# 3DS      259.00
# XB       257.74
# GB       255.46
# NES      251.05
# N64      218.68
# SNES     200.04
# GC       198.93
# XOne     159.32
# 2600      96.98
# WiiU      82.19
# PSV       54.07
# SAT       33.59
# GEN       30.77
# DC        15.95
# SCD        1.86
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: total_sales, dtype: float64

# %%
top_platform = platform_sales.nlargest(10)
top_platform
# Out:
# platform
# PS2     1255.77
# X360     971.42
# PS3      939.65
# Wii      907.51
# DS       806.10
# PS       730.86
# GBA      317.85
# PS4      314.14
# PSP      294.05
# PC       259.52
# Name: total_sales, dtype: float64

# %%
filter_df= df[df['year_of_release']!= 0]
platform_yearly_sales = filter_df.groupby(['platform','year_of_release'])['total_sales'].count().reset_index()
platform_yearly_sales.tail(50)
# Out:
#     platform  year_of_release  total_sales
# 187     SNES             1995           54
# 188     SNES             1996           30
# 189     SNES             1997            4
# 190     SNES             1998            2
# 191     SNES             1999            1
# 192     TG16             1995            2
# 193       WS             1999            2
# 194       WS             2000            2
# 195       WS             2001            2
# 196      Wii             2006           44
# 197      Wii             2007          185
# 198      Wii             2008          282
# 199      Wii             2009          325
# 200      Wii             2010          253
# 201      Wii             2011          143
# 202      Wii             2012           31
# 203      Wii             2013           12
# 204      Wii             2014            6
# 205      Wii             2015            4
# 206      Wii             2016            1
# 207     WiiU             2012           32
# 208     WiiU             2013           42
# 209     WiiU             2014           31
# 210     WiiU             2015           28
# 211     WiiU             2016           14
# 212     X360             2005           18
# 213     X360             2006           93
# 214     X360             2007          123
# 215     X360             2008          146
# 216     X360             2009          172
# 217     X360             2010          182
# 218     X360             2011          206
# 219     X360             2012          106
# 220     X360             2013           75
# 221     X360             2014           63
# 222     X360             2015           35
# 223     X360             2016           13
# 224       XB             2000            1
# 225       XB             2001           33
# 226       XB             2002          158
# 227       XB             2003          189
# 228       XB             2004          177
# 229       XB             2005          179
# 230       XB             2006           62
# 231       XB             2007            3
# 232       XB             2008            1
# 233     XOne             2013           19
# 234     XOne             2014           61
# 235     XOne             2015           80
# 236     XOne             2016           87

# %% [markdown]
# ##### In above data I noticed that a platform takes around 4-8 years to fade away. If we look at data for Wii it came in market in 2006 and it was at its peak in 2009 and then it started fading away and in 2016 we just see sales of 1. I would say newer platforms take 1-2 years to become popular and a year or 2 to fade away as well.

# %%
df= df[df['year_of_release']!= 0]

platform_sales = df.groupby('platform')['total_sales'].sum().sort_values(ascending= False)
platform_sales

top_5 = platform_sales.index[:5]
top_platform_data = df[df['platform'].isin(top_5)]
yearly = top_platform_data.groupby(['year_of_release', 'platform'])[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum()

# %%
plt.figure(figsize=(10,6))

for platform in top_5:
    platform_data = df[df['platform'] == platform]
    yearly_sales = platform_data.groupby('year_of_release')['total_sales'].sum()
    plt.plot(yearly_sales.index, yearly_sales.values, label=platform)

plt.legend()

# %% [markdown]
# #### From the above platform data we can interpret that PS2 and DS has shrinked. As PS2 have no sales from 2011 and DS has stopped the sales in 2013. PS2 was at its peak in 2004 and WII was in 2009.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 </h2>
#
#
# Good. </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Shoundn't we sort years and not values?
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment 2 </b>
#
#
# - The legend may seem confusing to a reader.
#
#
#
# - Labels should not include the underscore character.</div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# >  I noticed that a platform takes around 10 years to fade away so if we want to forecast for 2017 we would only need the data which is under 10 years.
#
# Would you please explain how you inferred it from the chart above that does not even tell us anything about platforms? </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Please follow the instructions :)
#
#
# - Look at how many games were released in different years. Is the data for every period significant?
#
#
#     Please display the distribution including all years. What can be inferred from the chart?
#
#
# - Look at how sales varied from platform to platform. Choose the platforms with the greatest total sales and build a distribution based on data for each year. Find platforms that used to be popular but now have zero sales. How long does it generally take for new platforms to appear and old ones to fade?
#
#
#     What can we say about the distribution and platforms? Can we identify the average lifespan? Which platforms used to be popular but now have zero sales? In order to answer these questions, we need to analyze sales distribution over the years. Take  top-10 (we do not need to have too many platforms on one chart) platforms and display their sales over time. Then take a look at the recent years. Which of these top platforms have almost zero sales?
#
#
#
#
# - Determine what period you should take data for. To do so, look at your answers to the previous questions. The data should allow you to build a model for 2017.
#
#
#
#     Would you do that? If you did that above, then it is not the best idea. Solving this task, I also took about 10 years first. But then I realized that the market is dynamic, everything is changing. Some popular genre may not remain popular 10 years later. And vice versa. During this time, several platform generations will change :) The industry is evolving, the games are getting better, the graphics is getting better and the users are getting more demanding. In such tasks, we need fresh information, fresh estimation. If we forecast for 2017, then who cares what happened 10 years ago?  Potentially profitable platforms can be easily selected with charts and pivot tables, but user portraits may change. If you look at the sales chart, you will see in which year the market stabilized after huge volume sales. We can also take the half of a lifetime period.
#
#
#
#
# - Work only with the data that you've decided is relevant. Disregard the data for previous years.
#
#
#     For this purpose, you can either change the current dataframe or create a new one.
#
#
#
# - Which platforms are leading in sales? Which ones are growing or shrinking? Select several potentially profitable platforms.
#
#
#     Answer this questions please and explain why you chose specific platforms. Please take the dataframe with the relevant years and display the distribution of platforms' sales over time. This chart will help you identify platforms that have growth potential.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# I see you added the overall sales distribution. Now, let's move on to the next tasks. Please make sure to finish them one by one.
#
#
#
# - Look at how sales varied from platform to platform. Choose the platforms with the greatest total sales and build a distribution based on data for each year. Find platforms that used to be popular but now have zero sales. How long does it generally take for new platforms to appear and old ones to fade?
#
#
#     What can we say about the distribution and platforms? Can we identify the average lifespan? Which platforms used to be popular but now have zero sales? In order to answer these questions, we need to analyze sales distribution over the years. Take  top-10 (we do not need to have too many platforms on one chart) platforms and display their sales over time. Then take a look at the recent years. Which of these top platforms have almost zero sales?
#
#
#
#
# - Determine what period you should take data for. To do so, look at your answers to the previous questions. The data should allow you to build a model for 2017.
#
#
#
#     Please read the comments carefully. As I have said before, 10 years is too much. If we look at the very first sales chart, we will see in which year the market stabilized after huge volume sales. Let's adjust this choice and take years from 2012 or 2013. Years before 2012 have huge sales volume, which can influence our distributions. Moreover, new platforms appeared in 2012-2013, which means that these huge sales were generated by older platforms that cannot be relevant for so many years.
#
#
#
#
# - Work only with the data that you've decided is relevant. Disregard the data for previous years.
#
#
#     For this purpose, you can either change the current dataframe or create a new one.
#
#
#
# - Which platforms are leading in sales? Which ones are growing or shrinking? Select several potentially profitable platforms.
#
#
#     Answer this questions please and explain why you chose specific platforms. Please take the dataframe with the relevant years and display the distribution of platforms' sales over time. This chart will help you identify platforms that have growth potential.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# It is unclear why you choose to analyze these 3 platforms given they are not popular in 2016.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# It's not clear which of the tasks you are trying to do here.  </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# > I am trying to look at the best performing platform PS3 performance over different years
#
#
# Why PS3? I've left a large comment above where I explained what we should do here. Please try to follow the steps I described. It will help you finish the project.  </div>

# %%
df['number_of_years'] = (2016 - df['year_of_release']).sort_values()
df
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 0         41.36     28.96      3.77         8.45          76.0         8.0
# 1         29.08      3.58      6.81         0.77           0.0         0.0
# 2         15.68     12.76      3.79         3.29          82.0         8.3
# 3         15.61     10.93      3.28         2.95          80.0         8.0
# 4         11.27      8.89     10.22         1.00           0.0         0.0
# ...         ...       ...       ...          ...           ...         ...
# 16710      0.00      0.00      0.01         0.00           0.0         0.0
# 16711      0.00      0.01      0.00         0.00           0.0         0.0
# 16712      0.00      0.00      0.01         0.00           0.0         0.0
# 16713      0.01      0.00      0.00         0.00           0.0         0.0
# 16714      0.00      0.00      0.01         0.00           0.0         0.0
#
#           rating  total_sales  number_of_years
# 0              E        82.54               10
# 1      not_rated        40.24               31
# 2              E        35.52                8
# 3              E        32.77                7
# 4      not_rated        31.38               20
# ...          ...          ...              ...
# 16710  not_rated         0.01                0
# 16711  not_rated         0.01               10
# 16712  not_rated         0.01                0
# 16713  not_rated         0.01               13
# 16714  not_rated         0.01                0
#
# [16445 rows x 13 columns]

# %% [markdown]
# #### In the above data I got the number of years of a platform so that I can get data which is under 5 years as it will be the most recent data and good for our future analysis.

# %%
df_2017 = df[df['number_of_years']< 5]
df_2017
# Out:
#                                 name platform  year_of_release         genre  \
# 16                Grand Theft Auto V      PS3             2013        Action
# 23                Grand Theft Auto V     X360             2013        Action
# 31         Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33               Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 34        Call of Duty: Black Ops II      PS3             2012       Shooter
# ...                              ...      ...              ...           ...
# 16703               Strawberry Nauts      PSV             2016     Adventure
# 16707               Aiyoku no Eustia      PSV             2014          Misc
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16         7.02      9.09      0.98         3.96          97.0         8.2
# 23         9.66      5.14      0.06         1.41          97.0         8.1
# 31         6.03      5.86      0.36         2.38           0.0         0.0
# 33         5.28      4.19      4.35         0.78           0.0         0.0
# 34         4.99      5.73      0.65         2.42          83.0         5.3
# ...         ...       ...       ...          ...           ...         ...
# 16703      0.00      0.00      0.01         0.00           0.0         0.0
# 16707      0.00      0.00      0.01         0.00           0.0         0.0
# 16710      0.00      0.00      0.01         0.00           0.0         0.0
# 16712      0.00      0.00      0.01         0.00           0.0         0.0
# 16714      0.00      0.00      0.01         0.00           0.0         0.0
#
#           rating  total_sales  number_of_years
# 16             M        21.05                3
# 23             M        16.27                3
# 31     not_rated        14.63                1
# 33     not_rated        14.60                3
# 34             M        13.79                4
# ...          ...          ...              ...
# 16703  not_rated         0.01                0
# 16707  not_rated         0.01                2
# 16710  not_rated         0.01                0
# 16712  not_rated         0.01                0
# 16714  not_rated         0.01                0
#
# [2886 rows x 13 columns]

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 </h2>
#
# It's a good decision for the following three reasons:
#
#
#
# 1. Years before 2012 have huge sales volume, which can influence our distributions.
#
#
# 2. New platforms appeared in 2012-2013, which means that these huge sales were generated by older platforms that cannot be relevant for so many years.
#
# 3. Since graphics and other components change fast, users' preferences change as well. It means that most people had different perceptions 10 years ago compared to their current perception.
#
#
# </div>

# %%
#Looking at the performance one of the top performing platform

total_platform = df_2017.groupby('platform')['total_sales'].sum().sort_values(ascending = False)
platform_sales = pd.DataFrame(total_platform)
game_counts = df_2017.groupby('platform')['name'].count()
platform_sales['game_counts'] = game_counts
platform_sales
# Out:
#           total_sales  game_counts
# platform
# PS4            314.14          392
# PS3            288.79          493
# X360           236.54          292
# 3DS            194.61          396
# XOne           159.32          247
# WiiU            82.19          147
# PC              62.65          250
# PSV             49.18          411
# Wii             35.37           54
# DS              12.55           31
# PSP             11.19          173

# %% [markdown]
# ## In the data above we can see the number of games by the plaform breakdown. Top performing platforms are PS4, PS3 and X360. PS3 released most of the games.

# %%
df_2017= df_2017[df_2017['year_of_release']!= 0]
platform_sales_2017 = df_2017.groupby('platform')['total_sales'].sum().sort_values(ascending= False)
platform_sales_2017

top_5 = platform_sales_2017.index[:5]
top_platform_data_2017 = df_2017[df_2017['platform'].isin(top_5)]
yearly_2017 = top_platform_data_2017.groupby(['year_of_release', 'platform'])[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum()

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 4</h2>
#
# > `df= df[df['year_of_release']!= 0]`
#
#
# We do not work with this dataframe anymore, do we need to do anything with it?
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 5 </h2>
#
#
# > `df_2017= df_2017[df_2017['year_of_release']!= 0]`
#
#
# We do not have zeros because we excluded irrelevant years. Try to omit unnecessary steps in your code.
#
# </div>

# %%
# # Plotting top performing platforms on line graph for better visualization

plt.figure(figsize=(10,6))

for platform in top_5:
    platform_data_2017 = df_2017[df_2017['platform'] == platform]
    yearly_sales_2017 = platform_data_2017.groupby('year_of_release')['total_sales'].sum()
    plt.plot(yearly_sales_2017.index, yearly_sales_2017.values, label=platform)

plt.legend()

# %% [markdown]
# ### Top performing platforms are PS4, XOne and 3DS based on above line graph. PS4's had highest total sale of around 120 million USD in 2015.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 </b>
#
# Be careful. Here you took platforms that have most total sales in these years. Of course, PS3 is an old platfrom that had enough time to sell a lot of games. But what if there's a brand new platform that did not have enough time to gain high sales volume?
#
#
# In order to choose promising platforms, please take all platforms within relevant time interval and look at how their sales change over time.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 4 </h2>
#
#
# Correct! Sometimes it is much easier to analyze a simple pivot table:
#
# </div>

# %%
# Reviewer's code 4

df_2017.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
# Out:
# platform           3DS     DS     PC     PS3     PS4   PSP    PSV    Wii  \
# year_of_release
# 2012             51.36  11.01  23.22  107.36     NaN  7.69  16.19  21.71
# 2013             56.57   1.54  12.38  113.25   25.99  3.14  10.59   8.59
# 2014             43.76    NaN  13.28   47.76  100.00  0.24  11.90   3.75
# 2015             27.78    NaN   8.52   16.82  118.90  0.12   6.25   1.14
# 2016             15.14    NaN   5.25    3.60   69.25   NaN   4.25   0.18
#
# platform          WiiU   X360   XOne
# year_of_release
# 2012             17.56  99.74    NaN
# 2013             21.65  88.58  18.96
# 2014             22.03  34.74  54.07
# 2015             16.35  11.96  60.14
# 2016              4.60   1.52  26.15

# %%
## Plotting 3DS platform on box plot for better visualization over years 
plt.figure(figsize=(12, 6))
df_2017.boxplot(column ='total_sales', by = 'platform')
plt.title('Boxplot grouped by  platform')
plt.xlabel(' platform')
plt.ylabel('total sales')
plt.ylim([0,3])
plt.suptitle('')
plt.show()

# %% [markdown]
# #####  The median for X360  is around 0.3 millions USD followed by XOne which is around 0.2 millions USD and 3DS is 0.1 millions USD.  Based on the box plot X360 is very popular platform. As majority of cutomer are using its video games.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
# Would you try to fix the following issues?
#
#
# - Try to display boxes on one chart.
#
#
# - Please apply the `ylim` because it is very hard to compare the boxes, since they are too small.
#
#
# Just take the `df_2017` dataframe and apply the `boxplot` method exactly like you did above. Then all platforms will be displayed on one chart. Then use the `plt.ylim(0,3)` command to limit the Y axis values. This is how the result should look like:
#
#
#
# ![image.png](attachment:image.png)
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 5</h2>
#
#
# A boxplot shows us a distribution, like a histogram. 2 pictures below represent it:
#
#
# ![image info](https://r-charts.com/en/distribution/histogram-boxplot_files/figure-html/histogram-boxplot.png)
#
#
# ![image.png](https://i.ytimg.com/vi/FPREzlHdWRY/maxresdefault.jpg)
#
#
#
# But the boxplot is better, since we don't have to think about `bins` parameter for a histogram. Boxplot also shows us some statistics, while histogram doesn't.
#
#
# What does our boxplot tell us about? Since we are plotting sum world sales per game, outliers are just some very popular games. I would even say bestsellers. And this is a very illustrative thing. Look at the 3DS. Small box and lots of outliers. This suggests that a large part of the sales volume comes from these outliers. At the same time, the XOne has a different situation: a large box, a long whisker and few outliers. This indicates that a wide variety of games are bought on XOne, and, moreover, in considerable quantities.
#
# That's why it may be useful to plot 2 graphs: with and without outliers. Just to evaluate the distribution.
#
# That's how you can interpret boxplots. </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
#
# > Build a box plot for the global sales of all games, broken down by platform. Are the differences in sales significant? What about average sales on various platforms? Describe your findings.
#
#
#
# We don't need to group by year here, the idea is to show the distribution (boxplot show the distribution) of the sales for each platform, taking into account every single game. So we just need to group by platform, that's all.</div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# The comment above is still relevant.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 </b>
#
# Please try to fix the issues above. Each box must represent a specific platform, not year.
#
# </div>

# %% [markdown]
# # Critic score vs User score

# %%
df_2017['critic_score_rescaled'] = df_2017['critic_score'] / 10

# %%
df_filtered= df_2017[df_2017['critic_score_rescaled']!=0]

# %%
plat_PS4= df_filtered[df_filtered['platform'] == 'PS4']
plat_PS4.plot(kind='scatter', x='critic_score_rescaled', y= 'total_sales', figsize=[10,5], color= 'blue', alpha =0.36)
plt.show()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# - Please don't forget to exclude zeros.
#
#
# - PS2 does not even have sales during recent years. Shouldn't we analyze one of the recently manufactured platforms instead?  </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# Zeros influence correlation coefficients.
#
#
# </div>

# %%
df_filter= df_2017[df_2017['user_score']!=0]

# %%
plat_PS4= df_filter[df_filter['platform'] == 'PS4']
plat_PS4.plot(kind='scatter', x='user_score', y= 'total_sales',figsize=[10,5], color= 'blue', alpha =0.36)
plt.show()

# %% [markdown]
# #### Comparision between critic score and user score. The user scores have negative affect on sales. We can see in the graph above as total sale increases the user score decreases. But that is not true for critic score.

# %%
print(plat_PS4[['critic_score_rescaled', 'total_sales']].corr())
# Out:
#                        critic_score_rescaled  total_sales
# critic_score_rescaled               1.000000     0.351933
# total_sales                         0.351933     1.000000

# %%
print(plat_PS4[[ 'user_score', 'total_sales']].corr())
# Out:
#              user_score  total_sales
# user_score     1.000000    -0.031957
# total_sales   -0.031957     1.000000

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 5 </h2>
#
# You did not fix the issue. In both cases, you use `plat_PS4` that is defined as follows: `plat_PS4= df_filter[df_filter['platform'] == 'PS4']`, and `df_filter` is defined as follows: `df_filter= df_2017[df_2017['user_score']!=0]`. As a result, you still have zeros in the critics score column, and these zeros change the correlation coefficient, influencing the results and conclusions.
#
#
# As I have said before, it is much better to just create two dataframes: one for critics' scores and one fore users' scores, so you should use `df_filtered` to display the correlation between sales and critics scores.
#
#
#
# In the next projects, please be careful with the code.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 </b>
#
# `plat_PS4` is defined as follows:
#
#
# ```python
#
# df_filter= df_2017[df_2017['user_score']!=0]
# plat_PS4= df_filter[df_filter['platform'] == 'PS4']
#
# ```
#
# So you did not exclude zeros in critics' scores.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b> Student's comment</b>
#     I have excluded zeros in user score or I would have got bunch of zeros in my graph.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
# > Student's comment I have excluded zeros in user score or I would have got bunch of zeros in my graph.
#
#
# Correct, you excluded them from the users' scores column and there are no zeros on the chart. But what about the correlation coefficients between sales and critics scores?
#
#
#
# Same issue below. </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# Moreover, there are rows that have users' scores and do not have critics' score and vice versa. If you delete rows that have Nan in any of these two columns, you may lose data. So it's better to create separate dataframes here: one for critics' scores analysis and one for users' scores analysis.
#
# </div>

# %% [markdown]
# #### For platform PS4 there is negative correlation between user score and total sales which means as the total sales increases the user score decreases. There is medium correlation between critic score and total sales.

# %%
plat_X360 = df_filtered[df_filtered['platform'] == 'X360']
plat_X360.plot(kind='scatter', x='critic_score_rescaled', y= 'total_sales', figsize=[10,5], color= 'blue', alpha =0.36)
plt.show()

# %%
plat_X360= df_filter[df_filter['platform'] == 'X360']
plat_X360.plot(kind='scatter', x='user_score', y= 'total_sales',figsize=[10,5], color= 'blue', alpha =0.36)
plt.show()

# %% [markdown]
# ##### The scores have minimal affect on sales. So it means that X360 sales was high because user and critics have similar review about the platform. Maybe X360 platforms have games which are similar reviews. Only very few games may have very high reviews.

# %%
print(plat_X360[['critic_score_rescaled', 'total_sales']].corr())
# Out:
#                        critic_score_rescaled  total_sales
# critic_score_rescaled               1.000000     0.255861
# total_sales                         0.255861     1.000000

# %%
print(plat_X360[[ 'user_score', 'total_sales']].corr())
# Out:
#              user_score  total_sales
# user_score     1.000000     0.006164
# total_sales    0.006164     1.000000

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 </b>
#
# Same issue.
# </div>

# %% [markdown]
# #### There is little correlation between critic score and total sales .There is no relation between user score and total sales.

# %%
total_game= df_2017[df_2017['name'] == 'Call of Duty: Black Ops II' ]
total_game.head(10)
# Out:
#                             name platform  year_of_release    genre  na_sales  \
# 34    Call of Duty: Black Ops II      PS3             2012  Shooter      4.99
# 35    Call of Duty: Black Ops II     X360             2012  Shooter      8.25
# 1227  Call of Duty: Black Ops II       PC             2012  Shooter      0.64
# 4706  Call of Duty: Black Ops II     WiiU             2012  Shooter      0.20
#
#       eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 34        5.73      0.65         2.42          83.0         5.3      M
# 35        4.24      0.07         1.12          83.0         4.8      M
# 1227      0.69      0.00         0.19          74.0         4.2      M
# 4706      0.18      0.00         0.03          81.0         6.9      M
#
#       total_sales  number_of_years  critic_score_rescaled
# 34          13.79                4                    8.3
# 35          13.68                4                    8.3
# 1227         1.52                4                    7.4
# 4706         0.41                4                    8.1

# %% [markdown]
# ####  We can see in above data the game Call of Duty Black Ops II has higher sales for PS3 platform than X360.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# Zeros influence correlation coefficients.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# Please do not forget about conclusions.
#
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# According to the task, we have to choose 1 platform, analyze how sales depend on critics' and users' scores, display scatter plots and calculate the correlation coefficients. Then we have to choose  2 or more other platforms, repeat the correlation analysis for them and compare the results. Would you add it?
#
#
# The wording in this task is ambiguous, but since we are comparing platforms, it is reasonable to take scores for all games on the platform within a chosen period. In other words, you do not need to check each game in the dataset.
#
# All you need here is to take 2 or more other platforms and repeat the analysis. Then compare the results. </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# There are zeros on the chart above.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# It will be great if you analyze more platforms.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# > `2017model platform are Xone, Wii, X360, PS3, 3DS, PS4, PC, WiiU, PSV.`
#
#
#
# How did you define that? Please keep in mind that a reader must understand your actions and the conclusions you make.
#
# </div>

# %%
total_genre = df_2017.groupby('genre')['total_sales'].sum().sort_values(ascending = False)
total_genre
# Out:
# genre
# Action          441.12
# Shooter         304.73
# Role-Playing    192.80
# Sports          181.07
# Misc             85.04
# Platform         61.00
# Racing           53.50
# Fighting         44.49
# Simulation       35.12
# Adventure        29.43
# Strategy         13.34
# Puzzle            4.89
# Name: total_sales, dtype: float64

# %%
## showing genre breakdown by total sales
total_genre.plot(kind = 'bar',
                 x = 'genre', 
                 y = 'total_sales',
                 xlabel = 'genre',
                 ylabel = 'total_sales',
                 rot= 50)
plt.show()

# %% [markdown]
# ## As we see the genre graph we can infer that the action games have most sales followed by shooter games. So the most profitable genre is action games. The genre with least profit is puzzle games.

# %%
## showing genre breakdown by total sales
plt.figure(figsize=(10, 100))
df_2017.boxplot(column ='total_sales', by = 'genre')
plt.title('Genre distribution based on sales')
plt.xlabel('genre')
plt.ylabel('total sales')
plt.ylim([0,3])
plt.xticks(rotation=90)
plt.suptitle('')
plt.show()

# %% [markdown]
# ##### Shooter games have median it looks like around 0.45 million usd and others have median much lower. So shooter games are more popular than sports games as sports games have the median of 0.2 million usd followed by action games with 0.15 million usd as median.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 </b>
#
# Please try yo use `ylim` here, because it's hard to compare the boxes.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
# Looks better.
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
# The medians are still hard to distinguish though.
# </div>

# %%
total_platform_avg = df_2017.groupby('platform')['total_sales'].median().sort_values()
total_platform_avg
# Out:
# platform
# PSP     0.03
# DS      0.05
# PSV     0.05
# PC      0.08
# 3DS     0.11
# Wii     0.18
# PS3     0.20
# PS4     0.20
# WiiU    0.22
# XOne    0.22
# X360    0.31
# Name: total_sales, dtype: float64

# %% [markdown]
# #### When we are observing the medians of different platforms we see that X360, XOne and WiiU has the highest median. Most of the data for X360 will be closer to 0.31.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
#
# Good.
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2 </h2>
#
#
# The results may change though.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# Please use a bar chart in order to display each genre on the X axis.   </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# - Is it possible that Action has made such volumes only due to the number of games? Maybe other genres have more sales per game unit. Please, do the same, but with median or average sales.
#
#
#
# - Try to display all genres, not just first and last 5. </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# - It's hard to read the labels on the X axis.
#
#
# - Each result must have a conclusion. Otherwise, it is unclear why you add this chart.
# </div>

# %% [markdown]
# # NA region

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# The distributions may change after we use the correct time interval, so don't forget to update the conclusions :)
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# Still relevant.
# </div>

# %%
total_share = df_2017['total_sales'].sum()
total_share
# Out:
# 1446.5300000000002

# %%
NA = df_2017.groupby('genre')['na_sales'].sum().sort_values(ascending=False).head()
NA
# Out:
# genre
# Action          177.84
# Shooter         144.77
# Sports           81.53
# Role-Playing     64.00
# Misc             38.19
# Name: na_sales, dtype: float64

# %%
NA = df_2017.groupby('platform')['na_sales'].sum().sort_values(ascending=False)
NA.head()
# Out:
# platform
# X360    140.05
# PS4     108.74
# PS3     103.38
# XOne     93.12
# 3DS      55.31
# Name: na_sales, dtype: float64

# %% [markdown]
# ### NA's  top 5 platform are X360, PS4, PS3, XOne, 3DS and top 5 genres are action, shooter, sports, role playing and misc. X360 is top performing platform in NA region.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# > NA's top 5 platform are X360, Wii, PS2, GG, SAT and top 5 genres are shooter, action, sports, misc and simulation.
#
#
# Are you sure? Is SAT in the top-5 list?
#
#
#
# Please display top 5 genres and platforms separately.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2</h2>
#
#
# Good.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# However, the reaults will change.
#
# </div>

# %%
total_na = df_2017['na_sales'].sum()
total_na
# Out:
# 590.97

# %%
na_share = total_na / total_share
na_share
# Out:
# 0.40854320339018196

# %% [markdown]
# #### NA has 40 % of the market share

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# What can be inferred from the two outputs above? Without a conclusion, it may be hard to understand what is going on here.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 2</h2>
#
#
# Looks better.
# </div>

# %% [markdown]
# # EU region

# %%
EU = df_2017.groupby('genre')['eu_sales'].sum().sort_values(ascending=False)
EU.head()
# Out:
# genre
# Action          159.34
# Shooter         113.47
# Sports           69.09
# Role-Playing     48.53
# Racing           27.29
# Name: eu_sales, dtype: float64

# %%
EU = df_2017.groupby('platform')['eu_sales'].sum().sort_values(ascending=False)
EU.head()
# Out:
# platform
# PS4     141.09
# PS3     106.86
# X360     74.52
# XOne     51.59
# 3DS      42.64
# Name: eu_sales, dtype: float64

# %% [markdown]
# ### EU's  top 5 platforms are PS4, PS3, X360, XOne, 3DS and the top 5 genres are action, shooter, sports, role playing, racing. PS4 is top performing platform in EU region.

# %%
total_eu = df_2017['eu_sales'].sum()
total_eu
# Out:
# 506.82000000000005

# %%
eu_share = total_eu / total_share
eu_share
# Out:
# 0.3503695049532329

# %% [markdown]
# #### EU has 35 % of the market share

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# Same issues here and further.
#
# </div>

# %% [markdown]
# # JP region

# %%
JP = df_2017.groupby('genre')['jp_sales'].sum().sort_values(ascending=False)
JP.head()
# Out:
# genre
# Role-Playing    65.44
# Action          52.80
# Misc            12.86
# Simulation      10.41
# Fighting         9.44
# Name: jp_sales, dtype: float64

# %%
JP = df_2017.groupby('platform')['jp_sales'].sum().sort_values(ascending=False)
JP.head()
# Out:
# platform
# 3DS     87.79
# PS3     35.29
# PSV     21.04
# PS4     15.96
# WiiU    13.01
# Name: jp_sales, dtype: float64

# %% [markdown]
# ### JP's top 5 platform are 3DS, PS3, PSV, PS4, WiiU. 3DS is top performing platform in JP region. The  top 5 genres are role playing, action, misc, simulation, fighting.

# %%
total_jp = df_2017['jp_sales'].sum()
total_jp
# Out:
# 192.58

# %%
jp_share = total_jp / total_share
jp_share
# Out:
# 0.13313239269147545

# %% [markdown]
# #### JP has 13 % of the market share

# %% [markdown]
# ## When comparing all 3 regions genres we can see action, shooter and sports are very popular in NA and EU regions. It looks like JP regions interests are little different than NA and EU as its popular genres are role playing and action. While observing at the market share I can say NA region has most market share followed by EU and JP.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 </h2>
#
#
# There are some similarities between Europe the Northern America, while  people in Japan prefer portable platforms and japanese market. We definitely should not recommend them XBox :)  In addition, Japanese also don't like shooters as much as in NA and EU people do.
#
# </div>

# %%
df_rating= df_2017.groupby(['platform','genre','rating'])['total_sales'].sum().sort_values(ascending=False)
df_rating
# Out:
# platform  genre         rating
# PS3       Action        M            68.15
# X360      Shooter       M            67.03
# 3DS       Role-Playing  not_rated    60.75
# PS4       Action        M            55.15
# PS3       Shooter       M            54.37
#                                      ...
# Wii       Racing        not_rated     0.01
# PC        Puzzle        E10+          0.01
# PSV       Puzzle        E10+          0.01
#           Platform      T             0.01
# Wii       Adventure     not_rated     0.01
# Name: total_sales, Length: 361, dtype: float64

# %% [markdown]
# #### As we can see in above data that mature rating contributes towards higher total sales. As adults are playing these games and they have more purchasing power than the teenagers.

# %% [markdown]
# ## Testing Hypothesis

# %%
avg_genre_action = df_filter[df_filter['genre'] == 'Action']['user_score'].dropna()
avg_genre_sport = df_filter[df_filter['genre'] == 'Sports']['user_score'].dropna()

alpha= 0.05

tstat, pvalue = st.ttest_ind(avg_genre_action, avg_genre_sport)

print('pvalue:', pvalue)

if (pvalue < alpha):
    print ("we can reject the hypothesis")
else:
    print ("we can't reject the hypothesis")
# Out:
# pvalue: 3.7163089460934874e-26
# we can reject the hypothesis

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 4 </h2>
#
#
# `df_filter` does not have zeros, good.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 </b>
#
#
# There are zeros in the data that we have to exclude.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
#
# - Are we supposed to use just two numbers in the statistical test? If it's just two numbers we need to compare, then why do we need any tests? Please refer to the lecture notes.
#
#
# - Don't forget to exclude zeros. </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# - Are we comparing sales? Please read the task carefully :)
#
#
# - Don't forget to exclude zeros.</div>

# %% [markdown]
# ### Null hypothesis is that the action and sports user ratings are same. Alternate hypothesis is that the user ratings are different. As we rejected the hypothesis that means the genres ratings are different. As pvalue is  3.71 that means 300 % probability of them being different. The probability is so high there is significant difference between two genres ratings.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Good. The null hypothesis always includes the equality sign. This is because the test does not understand exactly how we set the problem: we can say, for instance, let's make sure that they are not equal. Or that they are equal. And regardless of the purpose of our study, we always put equality at null hypothesis. Then the test result is interpreted correctly.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
# Pvalue should not be 0, 1, or Nan. Anytime you see these values, it may be a good idea to check the code or the arrays.
#
# </div>

# %%
avg_platform_XOne = df_filter[df_filter['platform']== 'XOne']['user_score'].dropna()
avg_platform_PC = df_filter[df_filter['platform']== 'PC']['user_score'].dropna()

alpha= 0.05

tstat, pvalue = st.ttest_ind(avg_platform_XOne, avg_platform_PC)

print('pvalue:', pvalue)

if (pvalue < alpha):
    print ("we can reject the hypothesis")
else:
    print ("we can't reject the hypothesis")
# Out:
# pvalue: 0.5535080500643661
# we can't reject the hypothesis

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 </b>
#
#
# There are zeros in the data that we have to exclude.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment </b>
#
#
# Same issues.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# Are we comparing sales here?</div>

# %% [markdown]
# ### Null hypothesis is that the platform XOne and PC user ratings are same. Alternate hypothesis is that the user ratings are different. As we can't reject the hypothesis that means the platforms ratings are same. As pvalue is 0.55 that means there is 6% probability of the user rating being same.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Correct.
# </div>

# %% [markdown]
# # Conclusion

# %% [markdown]
# NA region contributes to the most sales of the video games and most of the games with mature ratings are the best sellers. It could be because the adults are interested in action video games and they have more buying power.NA's top 5 platform are X360, PS4, PS3, XOne, 3DS and top 5 genres are action, shooter, sports, role playing and misc. X360 is top performing platform in NA region.
#
# EU's top 5 platforms are PS4, PS3, X360, XOne, 3DS and the top 5 genres are action, shooter, sports, role playing, racing. PS4 is top performing platform in EU region.
#
# JP's top 5 platform are 3DS, PS3, PSV, PS4, WiiU. 3DS is top performing platform in JP region. The top 5 genres are role playing, action, misc, simulation, fighting.
#
# When comparing all 3 regions genres we can see action, shooter and sports are very popular in NA and EU regions. It looks like JP regions interests are little different than NA and EU as its popular genres are role playing and action. While observing at the market share I can say NA region has most market share followed by EU and JP.
#
# As I am looking at the games released in different years I noticed highest amount of games were released from 2007 to 2011 maybe because entry to the market for new competitors were easier or government policies were linient so you can create and release more games. Another reason could be that the demand increased a lot during those years. It could be that the people started doing less outdoor activities and started to spend more time at home so you need entertainment at home.
#
# I noticed that a platform takes around 4-8 years to fade away.I would say newer platforms take 2 years to become popular and a year or 2 to fade away as well. The top platforms with potential of growth in 2017 will be PS4, XOne, 3DS.
#
# As we see the genre graph we can infer that the action games have most sales followed by shooter games. So the most profitable genre is action games. The genre with least profit is puzzle games.But when we looked at the median we got better picture and found out Shooter games have median it looks like around 0.5 million usd and others have median much lower. So shooter games are more popular than action games. But when we look at median of platforms X360 has highest median. The game 'Call of Duty Black Ops II' has higher sales for PS3 platform than X360.
#
# Mature rating contributes towards higher total sales. As adults are playing these games and they have more purchasing power than the teenagers. As action and shooter games in NA and EU regions contribute most to total sales.
#
# As we observed genre testing pvalue is 3.71 that means 300% probability of them being different. The probability is high so there is significant difference between two genres (action & sports) user ratings.
#
# As we observed platform testing pvalue is 0.6 that means there is 6% probability of the user rating being same for XOne and PC. So they are different.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 5</h2>
#
# Thank you very much!
#
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 </b>
#
# > The top platforms with potential of growth in 2017 will be PS#, PS$ and X360.
#
#
# Please don't forget to update the conclusion. PS3 and X360 cannot be promising, since they are dying.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment</h2>
#
#
# The conclusion is written well.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
#
# -
# > Growing platforms are PS3, X360, Wii, DS
#
#
# Please look at their sales. DS is not even supported in the 2016.
#
#
# - It will be great if you add a list of promising platforms and more information about each of the regions: 2-3 platforms, 2-3 genres and age ratings. Don't forget to update the final conclusion because the results will change.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# Please don't forget to update the final conclusion.
# </div>
